# %% [markdown]
# убрать из списка ниже все повторяющиеся элементы одного типа данных, идущие подряд.
# Предложите несколько вариантов решения

# %%
lst = [1, 2, 3, 1, 1, 1.0, 2, 1, '1', 2, 2, 2.0, 2, 1, 0, 0, '0']

# %%
dna = lst.copy()
def del1 (seq): #в упор, с игнорированием ошибки out of range (т.к. я работаю с i+1 символом - в конце списка ошибочка)
    try: 
        for i in range(len(seq)): 
            if (seq[i+1] == seq[i]) and (type(seq[i+1]) == type(seq[i])): 
                del seq[i+1]
    except: 
        pass 
    return seq
del1(dna)
# Out:
# [1, 2, 3, 1, 1.0, 2, 1, '1', 2, 2.0, 2, 1, 0, '0']

# %%
from Bio.Blast import NCBIWWW
from Bio.Seq import Seq
from Bio.Data import CodonTable
from Bio.SeqUtils import GC

DNA = Seq(list(sequ))
res = NCBIWWW.qblast('blastn','nt',DNA)
res
# Out:
# ['A', 'G', 'A', 'G', 'G', 'C', 'G', 'G', 'A', 'G', 'C', 'C', 'G', 'C', 'T', 'G', 'T', 'G', 'G', 'C', 'A', 'C', 'T', 'G', 'C', 'T', 'G', 'C', 'G', 'C', 'C', 'T', 'C', 'T', 'G', 'C', 'T', 'G', 'C', 'G', 'C', 'C', 'T', 'C', 'G', 'G', 'G', 'T', 'G', 'T', 'C', 'T', 'T', 'T', 'T', 'G', 'C', 'G', 'G', 'C', 'G', 'G', 'T', 'G', 'G', 'G', 'T', 'C', 'G', 'C', 'C', 'G', 'C', 'C', 'G', 'G', 'G', 'A', 'G', 'A', 'A', 'G', 'C', 'G', 'T', 'G', 'A', 'G', 'G', 'G', 'G', 'A', 'C', 'A', 'G', 'A', 'T', 'T', 'T', 'G', 'T', 'G', 'A', 'C', 'C', 'G', 'G', 'C', 'G', 'C', 'G', 'G', 'T', 'T', 'T', 'T', 'T', 'G', 'T', 'C', 'A', 'G', 'C', 'T', 'T', 'A', 'C', 'T', 'C', 'C', 'G', 'G', 'C', 'C', 'A', 'A', 'A', 'A', 'A', 'A', 'G', 'A', 'A', 'C', 'T', 'G', 'C', 'A', 'C', 'C', 'T', 'C', 'T', 'G', 'G', 'A', 'G', 'C', 'G', 'G', 'A', 'C', 'T', 'T', 'A', 'T', 'T', 'T', 'A', 'C', 'C', 'A', 'A', 'G', 'C', 'A', 'T', 'T', 'G', 'G', 'A', 'G', 'G', 'A', 'A', 'T', 'A', 'T', 'C', 'G', 'T', 'A', 'G', 'G', 'T', 'A', 'A', 'A', 'A', 'A
# ...

# %% [markdown]
# В ячейке ниже приводится биологическая последовательность под именем переменной seq.
# Предложите функцию для поиска всех гомополимерных участков в ней (идущие подряд одинаковые нуклеотиды)
# Определите, последовательностью какого гена является указанная последовательность.
# Все указанные действия следует выполнять из ячейки jupyter, не используя терминал.

# %%
sequ = '...'
